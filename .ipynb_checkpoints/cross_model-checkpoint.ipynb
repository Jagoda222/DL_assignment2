# %%
import h5py
import os
import matplotlib.pyplot as plt
import mne 
import sklearn

# %% [markdown]
# # Data Analysis

# %%
print("Working directory:", os.getcwd())
# Out:
# Working directory: C:\Users\irene\Documents\irene\Università\UU\DL\Final Project data\Final Project data\DL_assignment2

# %%
#code snippet to read one file
def get_dataset_name(filename_with_dir):
    filename_without_dir = filename_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = '_'.join(temp)  
    return dataset_name

filename_path = "../Cross/train/rest_164636_1.h5"


with h5py.File(filename_path, 'r') as f:
    dataset_name = get_dataset_name(filename_path)
    matrix = f.get(dataset_name)[()]
    print(type(matrix))
    print(matrix.shape)
# Out:
# <class 'numpy.ndarray'>
# (248, 35624)

# %%
#plot of data points for file /Intra/train/rest_105923_1.h5
plt.figure(figsize=(15, 6))

for i in range(matrix.shape[0]):  # 248 sensors (rows)
    plt.plot(matrix[i], alpha=0.5)  # `alpha` adds transparency to avoid overlap

plt.xlabel('Time')
plt.ylabel('Magnetometer Value')
plt.title('Time-Series of All Sensors')
plt.show()

# %%
data_dir = '../Cross/train'

# File listing
files = [f for f in os.listdir(data_dir) if f.endswith('.h5')]

# Preallocate lists
raws = []     # MNE Raw objects
labels = []   # Task labels

# Constants
sfreq = 2034  # Hz, number of samples per second in the signal >> for downsampling later
n_channels = 248 # channel = sensor
ch_names = [f'MEG {i:03d}' for i in range(n_channels)]
ch_types = ['mag'] * n_channels
info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types, verbose= False) #metadata; creates MNE info object to store everything about data but actual signal values

# extract full task label (e.g., task_motor, rest)
def get_task_label(filename):
    parts = filename.split('_')
    if parts[0] == 'rest':
        return 'rest'
    elif parts[0] == 'task':
        label_parts = []
        for part in parts[1:]:
            if part.isdigit():
                break
            label_parts.append(part)
        return '_'.join(label_parts)
    else:
        return 'unknown'


def create_dataset(data_dir):
# Loop through files
  for fname in sorted(files):
      fpath = os.path.join(data_dir, fname)
      task_label = get_task_label(fname)

      with h5py.File(fpath, 'r') as f:
          dataset_name = get_dataset_name(fname)
          data = f[dataset_name][()]  # shape: (248, 35624)

      # Create MNE Raw object
      raw = mne.io.RawArray(data, info, verbose=0)

      # Store
      raws.append(raw)
      labels.append(task_label)

  return raws, labels, info

raws, labels, info = create_dataset(data_dir)

# %%
single_sample = raws[0]
print(f"Number of recordings: {len(raws)}")
print(f"Unique tasks: {set(labels)}")
print(f"Info: {single_sample.info}")
data, times = single_sample[:, :]  # shape: (n_channels, n_times)
print("Min value:", data.min())
print("Max value:", data.max())
# Out:
# Number of recordings: 64
# Unique tasks: {'motor', 'story_math', 'working_memory', 'rest'}
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: MEG 000, MEG 001, MEG 002, MEG 003, MEG 004, MEG 005, MEG 006, ...
#  chs: 248 Magnetometers
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 1017.0 Hz
#  meas_date: unspecified
#  nchan: 248
#  projs: []
#  sfreq: 2034.0 Hz
# >
# Min value: -2.2335987226451692e-11
# Max value: 1.1083273188106091e-11

# %%
##Identify Bad Channels
from mne.preprocessing import find_bad_channels_lof
from collections import Counter

def identify_bad_channels(data, verbose = 0):
  all_bads = []
  bad_channels_per_trial = []

  for i, raw in enumerate(data):
      bads = mne.preprocessing.find_bad_channels_lof(raw, verbose = 0)
      bad_channels_per_trial.append(bads)
      if verbose == 1:
        print(f"Trial {i} - identified {len(bads)} bad channels: {bads}")

  # Count occurrences of each bad channel across all trials
  all_bad_channels = [ch for trial_bads in bad_channels_per_trial for ch in trial_bads]
  bad_counts = Counter(all_bad_channels)

  # Channels that appear as bad in every trial (count == number of trials)
  bad_in_all_trials = [ch for ch, count in bad_counts.items() if count == len(data)]

  if verbose == 1:
    print("Channels bad in all trials:", bad_in_all_trials)

  return bad_in_all_trials, bad_channels_per_trial


bad_in_all_trials, bad_channels_per_trial = identify_bad_channels(raws, verbose = 1)
# Out:
# Trial 0 - identified 4 bad channels: ['MEG 160', 'MEG 218', 'MEG 228', 'MEG 236']
# Trial 1 - identified 5 bad channels: ['MEG 160', 'MEG 218', 'MEG 219', 'MEG 228', 'MEG 236']
# Trial 2 - identified 7 bad channels: ['MEG 160', 'MEG 194', 'MEG 218', 'MEG 219', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 3 - identified 6 bad channels: ['MEG 160', 'MEG 218', 'MEG 219', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 4 - identified 7 bad channels: ['MEG 015', 'MEG 084', 'MEG 160', 'MEG 218', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 5 - identified 9 bad channels: ['MEG 015', 'MEG 048', 'MEG 073', 'MEG 084', 'MEG 160', 'MEG 218', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 6 - identified 10 bad channels: ['MEG 015', 'MEG 048', 'MEG 084', 'MEG 160', 'MEG 190', 'MEG 218', 'MEG 220', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 7 - identified 10 bad channels: ['MEG 015', 'MEG 048', 'MEG 073', 'MEG 084', 'MEG 160', 'MEG 190', 'MEG 218', 'MEG 223', 'MEG 228', 'MEG 236']
# Trial 8 - identified 8 bad channels: ['MEG 011', 'MEG 012', 'MEG 126', 'MEG 148', 'MEG 189', 'MEG 194', 'MEG 224', 'MEG 236']
# Trial 9 - identified 6 bad channels: ['MEG 011', 'MEG 126', 'MEG 148', 'MEG 194', 'MEG 224', 'MEG 236']
# Trial 10 - identified 9 bad channels: ['MEG 011', 'MEG 012', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 224', 'MEG 236']
# Trial 11 - identified 9 bad channels: ['MEG 011', 'MEG 012', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 224', 'MEG 236']
# Trial 12 - identified 10 bad channels: ['MEG 011', 'MEG 012', 'MEG 120', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 224', 'MEG 236']
# Trial 13 - identified 12 bad channels: ['MEG 011', 'MEG 012', 'MEG 120', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 217', 'MEG 222', 'MEG 224', 'MEG 236']
# Trial 14 - identified 12 bad channels: ['MEG 011', 'MEG 012', 'MEG 120', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 217', 'MEG 222', 'MEG 224', 'MEG 236']
# Trial 15 - identified 12 bad channels: ['MEG 011', 'MEG 012', 'MEG 120', 'MEG 126', 'MEG 148', 'MEG 185', 'MEG 187', 'MEG 194', 'MEG 217', 'MEG 222', 'MEG 224', 'MEG 236']
# Trial 16 - identified 3 bad channels: ['MEG 141', 'MEG 144', 'MEG 236']
# Trial 17 - identified 6 bad channels: ['MEG 027', 'MEG 099', 'MEG 141', 'MEG 144', 'MEG 206', 'MEG 236']
# Trial 18 - identified 9 bad channels: ['MEG 025', 'MEG 027', 'MEG 099', 'MEG 132', 'MEG 141', 'MEG 144', 'MEG 209', 'MEG 225', 'MEG 236']
# Trial 19 - identified 6 bad channels: ['MEG 027', 'MEG 099', 'MEG 141', 'MEG 144', 'MEG 211', 'MEG 236']
# Trial 20 - identified 33 bad channels: ['MEG 014', 'MEG 017', 'MEG 025', 'MEG 027', 'MEG 039', 'MEG 048', 'MEG 053', 'MEG 063', 'MEG 073', 'MEG 075', 'MEG 086', 'MEG 091', 'MEG 097', 'MEG 099', 'MEG 109', 'MEG 114', 'MEG 132', 'MEG 141', 'MEG 144', 'MEG 155', 'MEG 157', 'MEG 163', 'MEG 165', 'MEG 177', 'MEG 184', 'MEG 186', 'MEG 209', 'MEG 211', 'MEG 212', 'MEG 231', 'MEG 233', 'MEG 236', 'MEG 247']
# Trial 21 - identified 14 bad channels: ['MEG 025', 'MEG 073', 'MEG 109', 'MEG 114', 'MEG 141', 'MEG 144', 'MEG 163', 'MEG 184', 'MEG 197', 'MEG 209', 'MEG 211', 'MEG 212', 'MEG 231', 'MEG 236']
# Trial 22 - identified 29 bad channels: ['MEG 012', 'MEG 014', 'MEG 017', 'MEG 019', 'MEG 025', 'MEG 027', 'MEG 039', 'MEG 046', 'MEG 057', 'MEG 063', 'MEG 075', 'MEG 086', 'MEG 091', 'MEG 097', 'MEG 099', 'MEG 114', 'MEG 120', 'MEG 132', 'MEG 141', 'MEG 143', 'MEG 145', 'MEG 157', 'MEG 175', 'MEG 184', 'MEG 209', 'MEG 211', 'MEG 233', 'MEG 236', 'MEG 243']
# Trial 23 - identified 22 bad channels: ['MEG 012', 'MEG 014', 'MEG 019', 'MEG 027', 'MEG 039', 'MEG 075', 'MEG 078', 'MEG 089', 'MEG 097', 'MEG 099', 'MEG 112', 'MEG 114', 'MEG 120', 'MEG 132', 'MEG 141', 'MEG 143', 'MEG 145', 'MEG 157', 'MEG 184', 'MEG 209', 'MEG 233', 'MEG 236']
# Trial 24 - identified 4 bad channels: ['MEG 061', 'MEG 154', 'MEG 224', 'MEG 236']
# Trial 25 - identified 3 bad channels: ['MEG 025', 'MEG 061', 'MEG 236']
# Trial 26 - identified 5 bad channels: ['MEG 025', 'MEG 061', 'MEG 073', 'MEG 231', 'MEG 236']
# Trial 27 - identified 6 bad channels: ['MEG 025', 'MEG 061', 'MEG 063', 'MEG 184', 'MEG 225', 'MEG 236']
# Trial 28 - identified 8 bad channels: ['MEG 025', 'MEG 063', 'MEG 073', 'MEG 141', 'MEG 184', 'MEG 225', 'MEG 231', 'MEG 236']
# Trial 29 - identified 5 bad channels: ['MEG 025', 'MEG 061', 'MEG 063', 'MEG 231', 'MEG 236']
# Trial 30 - identified 6 bad channels: ['MEG 025', 'MEG 061', 'MEG 063', 'MEG 184', 'MEG 225', 'MEG 236']
# Trial 31 - identified 5 bad channels: ['MEG 025', 'MEG 061', 'MEG 063', 'MEG 184', 'MEG 236']
# Trial 32 - identified 1 bad channels: ['MEG 236']
# Trial 33 - identified 3 bad channels: ['MEG 073', 'MEG 114', 'MEG 236']
# Trial 34 - identified 7 bad channels: ['MEG 017', 'MEG 073', 'MEG 081', 'MEG 114', 'MEG 141', 'MEG 184', 'MEG 236']
# Trial 35 - identified 3 bad channels: ['MEG 081', 'MEG 184', 'MEG 236']
# Trial 36 - identified 2 bad channels: ['MEG 184', 'MEG 236']
# Trial 37 - identified 1 bad channels: ['MEG 236']
# Trial 38 - identified 1 bad channels: ['MEG 236']
# Trial 39 - identified 3 bad channels: ['MEG 073', 'MEG 114', 'MEG 236']
# Trial 40 - identified 3 bad channels: ['MEG 073', 'MEG 211', 'MEG 236']
# Trial 41 - identified 3 bad channels: ['MEG 073', 'MEG 211', 'MEG 236']
# Trial 42 - identified 2 bad channels: ['MEG 211', 'MEG 236']
# Trial 43 - identified 4 bad channels: ['MEG 028', 'MEG 144', 'MEG 206', 'MEG 236']
# Trial 44 - identified 4 bad channels: ['MEG 144', 'MEG 206', 'MEG 211', 'MEG 236']
# Trial 45 - identified 4 bad channels: ['MEG 141', 'MEG 144', 'MEG 211', 'MEG 236']
# Trial 46 - identified 9 bad channels: ['MEG 073', 'MEG 114', 'MEG 141', 'MEG 144', 'MEG 184', 'MEG 197', 'MEG 211', 'MEG 225', 'MEG 236']
# Trial 47 - identified 7 bad channels: ['MEG 028', 'MEG 073', 'MEG 144', 'MEG 184', 'MEG 206', 'MEG 211', 'MEG 236']
# Trial 48 - identified 5 bad channels: ['MEG 160', 'MEG 225', 'MEG 231', 'MEG 233', 'MEG 236']
# Trial 49 - identified 3 bad channels: ['MEG 225', 'MEG 233', 'MEG 236']
# Trial 50 - identified 14 bad channels: ['MEG 025', 'MEG 063', 'MEG 091', 'MEG 099', 'MEG 109', 'MEG 112', 'MEG 157', 'MEG 184', 'MEG 209', 'MEG 225', 'MEG 231', 'MEG 233', 'MEG 236', 'MEG 243']
# Trial 51 - identified 16 bad channels: ['MEG 017', 'MEG 073', 'MEG 099', 'MEG 112', 'MEG 114', 'MEG 141', 'MEG 144', 'MEG 163', 'MEG 175', 'MEG 184', 'MEG 197', 'MEG 211', 'MEG 212', 'MEG 225', 'MEG 233', 'MEG 236']
# Trial 52 - identified 10 bad channels: ['MEG 073', 'MEG 099', 'MEG 112', 'MEG 144', 'MEG 184', 'MEG 211', 'MEG 225', 'MEG 231', 'MEG 233', 'MEG 236']
# Trial 53 - identified 2 bad channels: ['MEG 233', 'MEG 236']
# Trial 54 - identified 6 bad channels: ['MEG 025', 'MEG 073', 'MEG 099', 'MEG 231', 'MEG 233', 'MEG 236']
# Trial 55 - identified 2 bad channels: ['MEG 099', 'MEG 236']
# Trial 56 - identified 6 bad channels: ['MEG 025', 'MEG 073', 'MEG 206', 'MEG 224', 'MEG 234', 'MEG 236']
# Trial 57 - identified 5 bad channels: ['MEG 025', 'MEG 073', 'MEG 206', 'MEG 224', 'MEG 236']
# Trial 58 - identified 5 bad channels: ['MEG 025', 'MEG 206', 'MEG 224', 'MEG 225', 'MEG 236']
# Trial 59 - identified 7 bad channels: ['MEG 025', 'MEG 073', 'MEG 114', 'MEG 224', 'MEG 225', 'MEG 234', 'MEG 236']
# Trial 60 - identified 10 bad channels: ['MEG 025', 'MEG 073', 'MEG 145', 'MEG 184', 'MEG 206', 'MEG 209', 'MEG 224', 'MEG 225', 'MEG 234', 'MEG 236']
# Trial 61 - identified 6 bad channels: ['MEG 025', 'MEG 145', 'MEG 209', 'MEG 224', 'MEG 225', 'MEG 236']
# Trial 62 - identified 8 bad channels: ['MEG 025', 'MEG 145', 'MEG 206', 'MEG 209', 'MEG 224', 'MEG 225', 'MEG 236', 'MEG 243']
# Trial 63 - identified 12 bad channels: ['MEG 017', 'MEG 025', 'MEG 073', 'MEG 141', 'MEG 144', 'MEG 145', 'MEG 184', 'MEG 206', 'MEG 209', 'MEG 224', 'MEG 236', 'MEG 243']
# Channels bad in all trials: ['MEG 236']

# %%
for i, raw in enumerate(raws):  # raw_trials is your list of 32 mne.io.Raw objects
    raws[i] = raw.copy().drop_channels(bad_in_all_trials)

# %%
single_sample = raws[23]
print(f"Number of recordings: {len(raws)}")
print(f"Unique tasks: {set(labels)}")
print(f"Info: {single_sample.info}")
data, times = single_sample[:, :]  # shape: (n_channels, n_times)
print("Min value:", data.min())
print("Max value:", data.max())
# Out:
# Number of recordings: 64
# Unique tasks: {'motor', 'story_math', 'working_memory', 'rest'}
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: MEG 000, MEG 001, MEG 002, MEG 003, MEG 004, MEG 005, MEG 006, ...
#  chs: 247 Magnetometers
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 1017.0 Hz
#  meas_date: unspecified
#  nchan: 247
#  projs: []
#  sfreq: 2034.0 Hz
# >
# Min value: -3.0990487953630463e-11
# Max value: 3.207076965106026e-11

# %%
##Bandpass Filtering, Downsampling, Normalization and Augmentation
def bandpass_filter(data, low_freq, high_freq):
  data_copy = data.copy()
  for raw in data_copy:
    raw.filter(l_freq=low_freq, h_freq=high_freq, filter_length='auto', verbose = False)
  return data_copy

def downsampling(data, new_freq):
  resampled_raws = []
  for entry in data:
      resampled = entry.copy().resample(new_freq, verbose=False)
      resampled_raws.append(resampled)

  resampled_arr = [raw.get_data() for raw in resampled_raws]  # each shape: (channels, times)

  # Convert to numpy array of shape (samples, channels, times)
  data = np.stack(resampled_arr)  # shape: (n_samples, n_channels, n_times)

  return data


def epoching_numpy(data, labels, sfreq, epoch_duration, overlap=0.3):
    """
    Epochs the downsampled MEG data.

    Args:
        data: np.ndarray of shape (n_trials, n_channels, n_times)
        labels: list of str, one per trial (e.g., 'motor', etc.)
        sfreq: sampling frequency of the d data
        epoch_duration: duration in seconds for each epoch
        overlap: proportion of overlap between epochs [0, 1)

    Returns:
        epoched_data: np.ndarray of shape (n_epochs, n_channels, epoch_samples)
        epoched_labels: list of str, task label for each epoch
        trial_ids: list of int, original trial index for each epoch
    """

    epoched_data = []
    epoched_labels = []
    trial_ids = []

    samples_per_epoch = int(epoch_duration * sfreq)
    step_size = int(samples_per_epoch * (1 - overlap))

    for trial_idx, (trial_data, label) in enumerate(zip(data, labels)):
        n_times = trial_data.shape[1]
        start_indices = np.arange(0, n_times - samples_per_epoch + 1, step_size)

        for start in start_indices:
            end = start + samples_per_epoch
            epoch = trial_data[:, start:end]  # shape: (n_channels, epoch_samples)
            epoched_data.append(epoch)
            epoched_labels.append(label)
            trial_ids.append(trial_idx)

    epoched_data = np.stack(epoched_data)  # shape: (n_epochs, n_channels, epoch_samples)

    return epoched_data, epoched_labels, trial_ids


def zscore_per_trial(trial, scale_factor=1e15):
    mean = trial.mean(axis=1, keepdims=True)  # mean per channel
    std = trial.std(axis=1, keepdims=True)    # std per channel
    normalized = (trial - mean) / std
    normalized *= scale_factor
    return normalized

# %%
import numpy as np
filtered_data = bandpass_filter(raws, 1, 40)
downsampled_data = downsampling(filtered_data, 250)

# %%
print(downsampled_data.shape)
# Out:
# (64, 247, 4379)

# %%
train_mean = np.mean(downsampled_data )
train_std = np.std(downsampled_data )

# %%
# Reshape into (num_blocks, 16, 247, 4379)
blocks = downsampled_data.reshape(-1, 16, 247, 4379)  # shape: (4, 16, 247, 4379)

# First 8 of each block → shape: (4, 8, 247, 4379)
first_half = blocks[:, :8, :, :]
# Last 8 of each block → shape: (4, 8, 247, 4379)
second_half = blocks[:, 8:, :, :]

# Reshape back to (32, 247, 4379)
subj_1 = first_half.reshape(-1, 247, 4379)
subj_2 = second_half.reshape(-1, 247, 4379)

# %%
# Split into chunks of 16
chunks = [labels[i:i+16] for i in range(0, 64, 16)]

# Take first 8 and last 8 from each chunk
labels_1 = [item for chunk in chunks for item in chunk[:8]]   # indices 0–7, 16–23, ...
labels_2 = [item for chunk in chunks for item in chunk[8:]]   # indices 8–15, 24–31, ...

# %% [markdown]
# ## Classification

# %%
from sklearn.preprocessing import LabelEncoder


# Then transpose for model input shape (n_trials, n_times, n_channels)
X_train = subj_1.transpose(0, 2, 1)
X_val = subj_2.transpose(0, 2, 1)
print(X_train.shape)
print(X_val.shape)


# Encode labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(labels_1)
y_val = label_encoder.fit_transform(labels_2)
print(len(y_train))
print(len(y_val))
# Out:
# (32, 4379, 247)
# (32, 4379, 247)
# 32
# 32

# %%
train_mean = X_train.mean(axis=0)
train_std = X_train.std(axis=0)
X_train_norm = (X_train - train_mean) / train_std
print(type(X_train_norm))
X_train_norm.shape[1:]
# Out:
# <class 'numpy.ndarray'>
# (4379, 247)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import *

from sklearn.model_selection import LeaveOneOut, train_test_split
from sklearn.metrics import accuracy_score

from sklearn.model_selection import KFold, StratifiedKFold, LeaveOneOut
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import GlobalMaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.linear_model import LogisticRegression

# %%
def baseline_plus(data, num_classes=4):
    model = Sequential([
        # Shape: (247 channels, 1000 time)
        Input(shape=(data.shape[1], data.shape[2])),

        Conv1D(64, kernel_size=15, padding='same'),
        BatchNormalization(),          # light BN → stabilises training
        Activation('relu'),
        MaxPooling1D(pool_size=4),
        Dropout(0.15),                 # small, won’t under‑fit

        Conv1D(128, kernel_size=7, padding='same'),
        BatchNormalization(),
        Activation('relu'),

        GlobalAveragePooling1D(),      # keeps params low
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.models import Model
#from tensorflow.keras.layers import Conv1D, Dense, LSTM, MaxPooling1D
'''
def cnn_att_lstm(input_shape, num_classes=4):
    model = tf.keras.models.Sequential([
                        tf.keras.layers.Conv1D(64, kernel_size=10, activation='relu', input_shape=input_shape),
                        tf.keras.layers.MaxPooling1D(pool_size=3),
                        tf.keras.layers.LSTM(64, return_sequences=False),
                        tf.keras.layers.Dense(num_classes, activation='softmax')
                        ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model
'''
# Out:
# "\ndef cnn_att_lstm(input_shape, num_classes=4):\n    model = tf.keras.models.Sequential([\n                        tf.keras.layers.Conv1D(64, kernel_size=10, activation='relu', input_shape=input_shape),\n                        tf.keras.layers.MaxPooling1D(pool_size=3),\n                        tf.keras.layers.LSTM(64, return_sequences=False),\n                        tf.keras.layers.Dense(num_classes, activation='softmax')\n                        ])\n\n    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])\n    return model\n"

# %%
def train_model(X_train, y_train, X_val, y_val, build_model_fn, epochs=50, batch_size=16):
    # Normalize using training set stats
    train_mean = X_train.mean(axis=0)
    train_std = X_train.std(axis=0)
    X_train_norm = (X_train - train_mean) / train_std
    X_val_norm = (X_val - train_mean) / train_std  # NOTE: Use training mean/std!

    # Build model
    model = build_model_fn(X_train_norm, num_classes=4)

    # Optional: Early stopping
    callbacks = [tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)]

    # Train
    history = model.fit(
        X_train_norm, y_train,
        validation_data=(X_val_norm, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluate
    val_acc = max(history.history['val_accuracy'])
    val_loss = min(history.history['val_loss'])
    y_pred = model.predict(X_val_norm).argmax(axis=1)

    print(f"Validation Accuracy: {val_acc:.4f}")
    print(f"Validation Loss: {val_loss:.4f}")

    return y_pred, history

# %%
y_true, y_pred = train_model(X_train, y_train, X_val, y_val, baseline_plus, epochs=20)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.1667 - loss: 1.3457 - val_accuracy: 0.2500 - val_loss: 3.9440
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.8333 - loss: 0.8992 - val_accuracy: 0.2500 - val_loss: 9.9971
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.9167 - loss: 0.6743 - val_accuracy: 0.2500 - val_loss: 15.5562
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.8750 - loss: 0.5649 - val_accuracy: 0.2500 - val_loss: 19.6241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# Validation Accuracy: 0.2500
# Validation Loss: 3.9440
